# %% [markdown]
# ### Imports

# %%
import time
import numpy as np
import pandas as pd
from typing import Callable, Union, List, Dict, Any, Tuple
from tqdm.notebook import tqdm

# %%
from index_utils import IndexUtil
from experiment_utils import ExperimentUtil

# %% [markdown]
# ### Prepare index/mappings/settings

# %%
INDEX_NAME = 'index_analyzers'

# %%
INDEX = IndexUtil(INDEX_NAME)

# %%
DEAFULT_SETTINGS = IndexUtil.get_default_settings()

# %%
def get_mappings(analyzer:str = 'stop-english_standard_analyzer'):
    return {
        "properties": {
            "article_id": {
                "type": "keyword"
            },
            "text": {
                "type": "text",
                "analyzer": analyzer
            },
        }
    }

# %%
def document_mapping_func(doc: Dict[str, Any])->Dict[str, Any]:
    return {
        'article_id': doc['uuid'],
        'text': doc['text'],
    }

# %% [markdown]
# ### Load datasets

# %%
DOCUMENTS_SQUAD, QUESTIONS_SQUAD = ExperimentUtil.load_dataset('squad_10k')
DOCUMENTS_SWIFT, QUESTIONS_SWIFT = ExperimentUtil.load_dataset('swift_ui')

# %% [markdown]
# ### Experiment

# %%
def prepare_analyzers_list():
    filtered_analyzers = ['shingle-1-2-3_standard_analyzer','stop-english_stemmer-english_shingle-1-3-3_standard_analyzer','shingle-1-3-3_letter_analyzer']
    filtered_analyzers = filtered_analyzers + ['stop-english_keyword-repeat_stemmer-porter2_remove_duplicates_standard_analyzer']
    filtered_analyzers = filtered_analyzers + ['keyword-repeat_stemmer-porter2_remove_duplicates_standard_analyzer']
    filtered_analyzers = filtered_analyzers + ['ngram_standard_analyzer','2-3-ngram_standard_analyzer']
#     filtered_analyzers = filtered_analyzers + [analyzer for analyzer in DEAFULT_SETTINGS['analysis']['analyzer'] if 'shingle' not in analyzer and 'pattern' not in analyzer]
    return filtered_analyzers

# %%
def test_analyzers_impact(documents, questions, index = INDEX_NAME, query_fuc = INDEX.default_query):
    analyzers_ls = []
    hits_top_10_ls = []
    hits_top_5_ls = []
    hits_top_3_ls = []
    hits_top_1_ls = []
    filtered_analyzers = prepare_analyzers_list()
    for analyzer in tqdm(filtered_analyzers):
        INDEX.delete_index()
        INDEX.create_index(mappings=get_mappings(analyzer))
        INDEX.index_all_docs(documents, document_mapping_func)
        analyzers_ls.append(analyzer)
        time.sleep(1)
        all_hits = ExperimentUtil.validate(index, questions, query_fuc)
        hits_10, hits_5, hit_3, hits_1 = all_hits['hits@10'], all_hits['hits@5'], all_hits['hits@3'], all_hits['hits@1']
        hits_top_10_ls.append(hits_10)
        hits_top_5_ls.append(hits_5)
        hits_top_3_ls.append(hit_3)
        hits_top_1_ls.append(hits_1)
    return pd.DataFrame.from_dict({
        'analyzer':analyzers_ls,
        'hits@10':hits_top_10_ls,
        'hits@5':hits_top_5_ls,
        'hits@3':hits_top_3_ls,
        'hits@1':hits_top_1_ls
    })

# %%
# analyzers_swift_df = test_analyzers_impact(DOCUMENTS_SWIFT, QUESTIONS_SWIFT)

# %%
# analyzers_squad_df = test_analyzers_impact(DOCUMENTS_SQUAD, QUESTIONS_SQUAD)

# %%
# analyzers_swift_df.to_csv('results/analyzers_impact_swift.csv')

# %%
# analyzers_squad_df.to_csv('results/analyzers_impact_squad.csv')

# %%
analyzers_swift_df = pd.read_csv('results/analyzers_impact_swift.csv', index_col=[0])
analyzers_squad_df = pd.read_csv('results/analyzers_impact_squad.csv', index_col=[0])

# %% [markdown]
# ### Explore results

# %% [markdown]
# #### SWIFT

# %%
analyzers_swift_df.sort_values('hits@10', ascending=False)
# Out:
#                                              analyzer   hits@10    hits@5  \
# 41                                   classic_analyzer  0.940217  0.858696
# 12                     stop-english_standard_analyzer  0.940217  0.864130
# 42                      stop-english_classic_analyzer  0.940217  0.853261
# 11                                  standard_analyzer  0.940217  0.864130
# 23                    stemmer-english_letter_analyzer  0.934783  0.864130
# 22                       stop-english_letter_analyzer  0.934783  0.869565
# 21                                    letter_analyzer  0.934783  0.875000
# 20     stop-english_stemmer-porter2_standard_analyzer  0.934783  0.853261
# 17     stop-english_stemmer-english_standard_analyzer  0.934783  0.864130
# 16                  stemmer-porter2_standard_analyzer  0.934783  0.864130
# 30       stop-english_stemmer-porter2_letter_analyzer  0.934783  0.864130
# 26                    stemmer-porter2_letter_analyzer  0.934783  0.864130
# 50      stop-english_stemmer-porter2_classic_analyzer  0.934783  0.853261
# 27       stop-english_stemmer-english_letter_analyzer  0.934783  0.864130
# 46                   stemmer-porter2_classic_analyzer  0.934783  0.864130
# 47      stop-english_stemmer-english_classic_analyzer  0.934783  0.864130
# 2                       shingle-1-3-3_letter_analyzer  0.934783  0.875000
# 10  keyword-repeat_stemmer-porter2_remove_duplicat...  0.929348  0.864130
# 9   stop-english_keyword-repeat_stemmer-porter2_re...  0.929348  0.858696
# 43                   stemmer-english_classic_analyzer  0.929348  0.869565
# 18  stop-english_stemmer-lightenglish_standard_ana...  0.929348  0.875000
# 48  stop-english_stemmer-lightenglish_classic_anal...  0.929348  0.869565
# 4   keyword-repeat_stemmer-porter2_remove_duplicat...  0.929348  0.864130
# 3   stop-english_keyword-repeat_stemmer-porter2_re...  0.929348  0.858696
# 24               stemmer-lightenglish_letter_analyzer  0.929348  0.880435
# 13                  stemmer-english_standard_analyzer  0.929348  0.869565
# 14             stemmer-lightenglish_standard_analyzer  0.923913  0.875000
# 44              stemmer-lightenglish_classic_analyzer  0.923913  0.869565
# 28  stop-english_stemmer-lightenglish_letter_analyzer  0.923913  0.885870
# 0                     shingle-1-2-3_standard_analyzer  0.918478  0.853261
# 29        stop-english_stemmer-lovins_letter_analyzer  0.918478  0.869565
# 25                     stemmer-lovins_letter_analyzer  0.918478  0.875000
# 49       stop-english_stemmer-lovins_classic_analyzer  0.913043  0.869565
# 45                    stemmer-lovins_classic_analyzer  0.913043  0.869565
# 15                   stemmer-lovins_standard_analyzer  0.913043  0.869565
# 19      stop-english_stemmer-lovins_standard_analyzer  0.913043  0.864130
# 1   stop-english_stemmer-english_shingle-1-3-3_sta...  0.836957  0.739130
# 37   stop-english_stemmer-english_whitespace_analyzer  0.690217  0.625000
# 31                                whitespace_analyzer  0.684783  0.614130
# 40   stop-english_stemmer-porter2_whitespace_analyzer  0.684783  0.630435
# 38  stop-english_stemmer-lightenglish_whitespace_a...  0.684783  0.630435
# 36                stemmer-porter2_whitespace_analyzer  0.684783  0.619565
# 39    stop-english_stemmer-lovins_whitespace_analyzer  0.679348  0.625000
# 33                stemmer-english_whitespace_analyzer  0.679348  0.619565
# 32                   stop-english_whitespace_analyzer  0.679348  0.625000
# 35                 stemmer-lovins_whitespace_analyzer  0.673913  0.608696
# 34           stemmer-lightenglish_whitespace_analyzer  0.673913  0.614130
# 8                         2-3-ngram_standard_analyzer  0.396739  0.271739
# 6                         2-3-ngram_standard_analyzer  0.396739  0.271739
# 7                             ngram_standard_analyzer  0.125000  0.059783
# 5                             ngram_standard_analyzer  0.125000  0.059783
#
#       hits@3    hits@1
# 41  0.793478  0.592391
# 12  0.804348  0.603261
# 42  0.798913  0.586957
# 11  0.798913  0.608696
# 23  0.804348  0.592391
# 22  0.815217  0.592391
# 21  0.809783  0.603261
# 20  0.793478  0.581522
# 17  0.798913  0.581522
# 16  0.793478  0.581522
# 30  0.788043  0.592391
# 26  0.798913  0.592391
# 50  0.793478  0.570652
# 27  0.793478  0.586957
# 46  0.793478  0.570652
# 47  0.798913  0.570652
# 2   0.798913  0.592391
# 10  0.788043  0.586957
# 9   0.777174  0.576087
# 43  0.793478  0.565217
# 18  0.820652  0.570652
# 48  0.815217  0.559783
# 4   0.788043  0.586957
# 3   0.777174  0.576087
# 24  0.820652  0.581522
# 13  0.793478  0.581522
# 14  0.798913  0.559783
# 44  0.798913  0.548913
# 28  0.820652  0.586957
# 0   0.788043  0.576087
# 29  0.777174  0.565217
# 25  0.788043  0.554348
# 49  0.788043  0.538043
# 45  0.782609  0.538043
# 15  0.782609  0.559783
# 19  0.788043  0.554348
# 1   0.673913  0.467391
# 37  0.538043  0.375000
# 31  0.532609  0.380435
# 40  0.538043  0.375000
# 38  0.554348  0.396739
# 36  0.527174  0.385870
# 39  0.543478  0.385870
# 33  0.527174  0.385870
# 32  0.538043  0.364130
# 35  0.532609  0.380435
# 34  0.543478  0.402174
# 8   0.233696  0.135870
# 6   0.233696  0.135870
# 7   0.043478  0.016304
# 5   0.043478  0.016304

# %%
analyzers_swift_df.sort_values('hits@5', ascending=False)
# Out:
#                                              analyzer   hits@10    hits@5  \
# 28  stop-english_stemmer-lightenglish_letter_analyzer  0.923913  0.885870
# 24               stemmer-lightenglish_letter_analyzer  0.929348  0.880435
# 25                     stemmer-lovins_letter_analyzer  0.918478  0.875000
# 18  stop-english_stemmer-lightenglish_standard_ana...  0.929348  0.875000
# 14             stemmer-lightenglish_standard_analyzer  0.923913  0.875000
# 21                                    letter_analyzer  0.934783  0.875000
# 2                       shingle-1-3-3_letter_analyzer  0.934783  0.875000
# 48  stop-english_stemmer-lightenglish_classic_anal...  0.929348  0.869565
# 29        stop-english_stemmer-lovins_letter_analyzer  0.918478  0.869565
# 49       stop-english_stemmer-lovins_classic_analyzer  0.913043  0.869565
# 45                    stemmer-lovins_classic_analyzer  0.913043  0.869565
# 44              stemmer-lightenglish_classic_analyzer  0.923913  0.869565
# 13                  stemmer-english_standard_analyzer  0.929348  0.869565
# 43                   stemmer-english_classic_analyzer  0.929348  0.869565
# 15                   stemmer-lovins_standard_analyzer  0.913043  0.869565
# 22                       stop-english_letter_analyzer  0.934783  0.869565
# 27       stop-english_stemmer-english_letter_analyzer  0.934783  0.864130
# 30       stop-english_stemmer-porter2_letter_analyzer  0.934783  0.864130
# 23                    stemmer-english_letter_analyzer  0.934783  0.864130
# 26                    stemmer-porter2_letter_analyzer  0.934783  0.864130
# 16                  stemmer-porter2_standard_analyzer  0.934783  0.864130
# 19      stop-english_stemmer-lovins_standard_analyzer  0.913043  0.864130
# 17     stop-english_stemmer-english_standard_analyzer  0.934783  0.864130
# 12                     stop-english_standard_analyzer  0.940217  0.864130
# 11                                  standard_analyzer  0.940217  0.864130
# 10  keyword-repeat_stemmer-porter2_remove_duplicat...  0.929348  0.864130
# 46                   stemmer-porter2_classic_analyzer  0.934783  0.864130
# 47      stop-english_stemmer-english_classic_analyzer  0.934783  0.864130
# 4   keyword-repeat_stemmer-porter2_remove_duplicat...  0.929348  0.864130
# 41                                   classic_analyzer  0.940217  0.858696
# 9   stop-english_keyword-repeat_stemmer-porter2_re...  0.929348  0.858696
# 3   stop-english_keyword-repeat_stemmer-porter2_re...  0.929348  0.858696
# 42                      stop-english_classic_analyzer  0.940217  0.853261
# 0                     shingle-1-2-3_standard_analyzer  0.918478  0.853261
# 50      stop-english_stemmer-porter2_classic_analyzer  0.934783  0.853261
# 20     stop-english_stemmer-porter2_standard_analyzer  0.934783  0.853261
# 1   stop-english_stemmer-english_shingle-1-3-3_sta...  0.836957  0.739130
# 40   stop-english_stemmer-porter2_whitespace_analyzer  0.684783  0.630435
# 38  stop-english_stemmer-lightenglish_whitespace_a...  0.684783  0.630435
# 32                   stop-english_whitespace_analyzer  0.679348  0.625000
# 39    stop-english_stemmer-lovins_whitespace_analyzer  0.679348  0.625000
# 37   stop-english_stemmer-english_whitespace_analyzer  0.690217  0.625000
# 33                stemmer-english_whitespace_analyzer  0.679348  0.619565
# 36                stemmer-porter2_whitespace_analyzer  0.684783  0.619565
# 31                                whitespace_analyzer  0.684783  0.614130
# 34           stemmer-lightenglish_whitespace_analyzer  0.673913  0.614130
# 35                 stemmer-lovins_whitespace_analyzer  0.673913  0.608696
# 8                         2-3-ngram_standard_analyzer  0.396739  0.271739
# 6                         2-3-ngram_standard_analyzer  0.396739  0.271739
# 7                             ngram_standard_analyzer  0.125000  0.059783
# 5                             ngram_standard_analyzer  0.125000  0.059783
#
#       hits@3    hits@1
# 28  0.820652  0.586957
# 24  0.820652  0.581522
# 25  0.788043  0.554348
# 18  0.820652  0.570652
# 14  0.798913  0.559783
# 21  0.809783  0.603261
# 2   0.798913  0.592391
# 48  0.815217  0.559783
# 29  0.777174  0.565217
# 49  0.788043  0.538043
# 45  0.782609  0.538043
# 44  0.798913  0.548913
# 13  0.793478  0.581522
# 43  0.793478  0.565217
# 15  0.782609  0.559783
# 22  0.815217  0.592391
# 27  0.793478  0.586957
# 30  0.788043  0.592391
# 23  0.804348  0.592391
# 26  0.798913  0.592391
# 16  0.793478  0.581522
# 19  0.788043  0.554348
# 17  0.798913  0.581522
# 12  0.804348  0.603261
# 11  0.798913  0.608696
# 10  0.788043  0.586957
# 46  0.793478  0.570652
# 47  0.798913  0.570652
# 4   0.788043  0.586957
# 41  0.793478  0.592391
# 9   0.777174  0.576087
# 3   0.777174  0.576087
# 42  0.798913  0.586957
# 0   0.788043  0.576087
# 50  0.793478  0.570652
# 20  0.793478  0.581522
# 1   0.673913  0.467391
# 40  0.538043  0.375000
# 38  0.554348  0.396739
# 32  0.538043  0.364130
# 39  0.543478  0.385870
# 37  0.538043  0.375000
# 33  0.527174  0.385870
# 36  0.527174  0.385870
# 31  0.532609  0.380435
# 34  0.543478  0.402174
# 35  0.532609  0.380435
# 8   0.233696  0.135870
# 6   0.233696  0.135870
# 7   0.043478  0.016304
# 5   0.043478  0.016304

# %% [markdown]
# #### SQUAD

# %%
analyzers_squad_df.sort_values('hits@10', ascending=False)
# Out:
#                                              analyzer  hits@10  hits@5  \
# 10     stop-english_stemmer-porter2_standard_analyzer    0.928   0.896
# 3   stop-english_keyword-repeat_stemmer-porter2_re...    0.927   0.894
# 40      stop-english_stemmer-porter2_classic_analyzer    0.926   0.894
# 4   keyword-repeat_stemmer-porter2_remove_duplicat...    0.924   0.901
# 6                   stemmer-porter2_standard_analyzer    0.924   0.902
# 36                   stemmer-porter2_classic_analyzer    0.922   0.899
# 7      stop-english_stemmer-english_standard_analyzer    0.918   0.886
# 37      stop-english_stemmer-english_classic_analyzer    0.916   0.883
# 4              stemmer-lightenglish_standard_analyzer    0.916   0.890
# 17       stop-english_stemmer-english_letter_analyzer    0.915   0.880
# 5                    stemmer-lovins_standard_analyzer    0.915   0.879
# 3                   stemmer-english_standard_analyzer    0.915   0.886
# 20       stop-english_stemmer-porter2_letter_analyzer    0.915   0.879
# 33                   stemmer-english_classic_analyzer    0.914   0.882
# 38  stop-english_stemmer-lightenglish_classic_anal...    0.914   0.886
# 35                    stemmer-lovins_classic_analyzer    0.914   0.876
# 34              stemmer-lightenglish_classic_analyzer    0.914   0.887
# 18  stop-english_stemmer-lightenglish_letter_analyzer    0.914   0.886
# 14               stemmer-lightenglish_letter_analyzer    0.914   0.890
# 8   stop-english_stemmer-lightenglish_standard_ana...    0.914   0.889
# 16                    stemmer-porter2_letter_analyzer    0.912   0.884
# 9       stop-english_stemmer-lovins_standard_analyzer    0.912   0.878
# 13                    stemmer-english_letter_analyzer    0.912   0.884
# 39       stop-english_stemmer-lovins_classic_analyzer    0.912   0.877
# 15                     stemmer-lovins_letter_analyzer    0.910   0.876
# 19        stop-english_stemmer-lovins_letter_analyzer    0.907   0.870
# 1                                   standard_analyzer    0.905   0.871
# 32                      stop-english_classic_analyzer    0.905   0.868
# 2                       shingle-1-3-3_letter_analyzer    0.904   0.865
# 2                      stop-english_standard_analyzer    0.904   0.868
# 12                       stop-english_letter_analyzer    0.904   0.862
# 11                                    letter_analyzer    0.904   0.867
# 31                                   classic_analyzer    0.904   0.870
# 0                     shingle-1-2-3_standard_analyzer    0.900   0.870
# 0                     shingle-1-2-3_standard_analyzer    0.899   0.870
# 1   stop-english_stemmer-english_shingle-1-3-3_sta...    0.860   0.816
# 26                stemmer-porter2_whitespace_analyzer    0.811   0.757
# 24           stemmer-lightenglish_whitespace_analyzer    0.798   0.753
# 30   stop-english_stemmer-porter2_whitespace_analyzer    0.798   0.749
# 28  stop-english_stemmer-lightenglish_whitespace_a...    0.794   0.742
# 23                stemmer-english_whitespace_analyzer    0.794   0.746
# 27   stop-english_stemmer-english_whitespace_analyzer    0.787   0.732
# 25                 stemmer-lovins_whitespace_analyzer    0.785   0.741
# 29    stop-english_stemmer-lovins_whitespace_analyzer    0.781   0.728
# 21                                whitespace_analyzer    0.772   0.715
# 22                   stop-english_whitespace_analyzer    0.764   0.710
# 6                         2-3-ngram_standard_analyzer    0.072   0.055
# 5                             ngram_standard_analyzer    0.001   0.000
#
#     hits@3  hits@1
# 10   0.872   0.766
# 3    0.868   0.767
# 40   0.869   0.765
# 4    0.870   0.771
# 6    0.867   0.764
# 36   0.865   0.765
# 7    0.858   0.751
# 37   0.854   0.750
# 4    0.857   0.759
# 17   0.852   0.748
# 5    0.851   0.747
# 3    0.849   0.751
# 20   0.852   0.749
# 33   0.847   0.752
# 38   0.857   0.752
# 35   0.849   0.747
# 34   0.855   0.760
# 18   0.855   0.749
# 14   0.856   0.753
# 8    0.859   0.754
# 16   0.852   0.748
# 9    0.850   0.737
# 13   0.850   0.747
# 39   0.849   0.736
# 15   0.842   0.738
# 19   0.843   0.732
# 1    0.830   0.717
# 32   0.835   0.715
# 2    0.827   0.720
# 2    0.835   0.716
# 12   0.832   0.710
# 11   0.830   0.716
# 31   0.830   0.719
# 0    0.833   0.712
# 0    0.833   0.712
# 1    0.776   0.652
# 26   0.711   0.578
# 24   0.699   0.567
# 30   0.709   0.566
# 28   0.694   0.560
# 23   0.696   0.561
# 27   0.693   0.555
# 25   0.686   0.561
# 29   0.682   0.560
# 21   0.679   0.539
# 22   0.673   0.536
# 6    0.042   0.025
# 5    0.000   0.000

# %%
analyzers_squad_df.sort_values('hits@5', ascending=False)
# Out:
#                                              analyzer  hits@10  hits@5  \
# 6                   stemmer-porter2_standard_analyzer    0.924   0.902
# 4   keyword-repeat_stemmer-porter2_remove_duplicat...    0.924   0.901
# 36                   stemmer-porter2_classic_analyzer    0.922   0.899
# 10     stop-english_stemmer-porter2_standard_analyzer    0.928   0.896
# 40      stop-english_stemmer-porter2_classic_analyzer    0.926   0.894
# 3   stop-english_keyword-repeat_stemmer-porter2_re...    0.927   0.894
# 14               stemmer-lightenglish_letter_analyzer    0.914   0.890
# 4              stemmer-lightenglish_standard_analyzer    0.916   0.890
# 8   stop-english_stemmer-lightenglish_standard_ana...    0.914   0.889
# 34              stemmer-lightenglish_classic_analyzer    0.914   0.887
# 38  stop-english_stemmer-lightenglish_classic_anal...    0.914   0.886
# 18  stop-english_stemmer-lightenglish_letter_analyzer    0.914   0.886
# 7      stop-english_stemmer-english_standard_analyzer    0.918   0.886
# 3                   stemmer-english_standard_analyzer    0.915   0.886
# 16                    stemmer-porter2_letter_analyzer    0.912   0.884
# 13                    stemmer-english_letter_analyzer    0.912   0.884
# 37      stop-english_stemmer-english_classic_analyzer    0.916   0.883
# 33                   stemmer-english_classic_analyzer    0.914   0.882
# 17       stop-english_stemmer-english_letter_analyzer    0.915   0.880
# 5                    stemmer-lovins_standard_analyzer    0.915   0.879
# 20       stop-english_stemmer-porter2_letter_analyzer    0.915   0.879
# 9       stop-english_stemmer-lovins_standard_analyzer    0.912   0.878
# 39       stop-english_stemmer-lovins_classic_analyzer    0.912   0.877
# 35                    stemmer-lovins_classic_analyzer    0.914   0.876
# 15                     stemmer-lovins_letter_analyzer    0.910   0.876
# 1                                   standard_analyzer    0.905   0.871
# 31                                   classic_analyzer    0.904   0.870
# 0                     shingle-1-2-3_standard_analyzer    0.900   0.870
# 0                     shingle-1-2-3_standard_analyzer    0.899   0.870
# 19        stop-english_stemmer-lovins_letter_analyzer    0.907   0.870
# 32                      stop-english_classic_analyzer    0.905   0.868
# 2                      stop-english_standard_analyzer    0.904   0.868
# 11                                    letter_analyzer    0.904   0.867
# 2                       shingle-1-3-3_letter_analyzer    0.904   0.865
# 12                       stop-english_letter_analyzer    0.904   0.862
# 1   stop-english_stemmer-english_shingle-1-3-3_sta...    0.860   0.816
# 26                stemmer-porter2_whitespace_analyzer    0.811   0.757
# 24           stemmer-lightenglish_whitespace_analyzer    0.798   0.753
# 30   stop-english_stemmer-porter2_whitespace_analyzer    0.798   0.749
# 23                stemmer-english_whitespace_analyzer    0.794   0.746
# 28  stop-english_stemmer-lightenglish_whitespace_a...    0.794   0.742
# 25                 stemmer-lovins_whitespace_analyzer    0.785   0.741
# 27   stop-english_stemmer-english_whitespace_analyzer    0.787   0.732
# 29    stop-english_stemmer-lovins_whitespace_analyzer    0.781   0.728
# 21                                whitespace_analyzer    0.772   0.715
# 22                   stop-english_whitespace_analyzer    0.764   0.710
# 6                         2-3-ngram_standard_analyzer    0.072   0.055
# 5                             ngram_standard_analyzer    0.001   0.000
#
#     hits@3  hits@1
# 6    0.867   0.764
# 4    0.870   0.771
# 36   0.865   0.765
# 10   0.872   0.766
# 40   0.869   0.765
# 3    0.868   0.767
# 14   0.856   0.753
# 4    0.857   0.759
# 8    0.859   0.754
# 34   0.855   0.760
# 38   0.857   0.752
# 18   0.855   0.749
# 7    0.858   0.751
# 3    0.849   0.751
# 16   0.852   0.748
# 13   0.850   0.747
# 37   0.854   0.750
# 33   0.847   0.752
# 17   0.852   0.748
# 5    0.851   0.747
# 20   0.852   0.749
# 9    0.850   0.737
# 39   0.849   0.736
# 35   0.849   0.747
# 15   0.842   0.738
# 1    0.830   0.717
# 31   0.830   0.719
# 0    0.833   0.712
# 0    0.833   0.712
# 19   0.843   0.732
# 32   0.835   0.715
# 2    0.835   0.716
# 11   0.830   0.716
# 2    0.827   0.720
# 12   0.832   0.710
# 1    0.776   0.652
# 26   0.711   0.578
# 24   0.699   0.567
# 30   0.709   0.566
# 23   0.696   0.561
# 28   0.694   0.560
# 25   0.686   0.561
# 27   0.693   0.555
# 29   0.682   0.560
# 21   0.679   0.539
# 22   0.673   0.536
# 6    0.042   0.025
# 5    0.000   0.000
