# %% [markdown]
# ### Imports

# %%
import time
import pandas as pd
from typing import Callable, Union, List, Dict, Any, Tuple
from tqdm.notebook import tqdm

from index_utils import IndexUtil
from experiment_utils import ExperimentUtil
from analyzer_utils import AnalyzerUtil

# %% [markdown]
# ### Prepare index/mappings/settings

# %%
INDEX_NAME = 'index_phonemes'

# %%
INDEX = IndexUtil(INDEX_NAME)

# %%
def get_settings():
    return {
        "number_of_shards": 1,
        "index": {
          "analysis": {
            "analyzer": {
              "phonetic_analyzer": {
                "tokenizer": "standard",
                "filter": [
                  "lowercase",
                  "metaphone_filter"
                ]
              },
            "phonetic_analyzer_no_replacement": {
                "tokenizer": "standard",
                "filter": [
                  "lowercase",
                  "metaphone_filter_no_replacement"
                ]
              },
            "stop-english_standard_analyzer": {
                "type": "custom",
                "tokenizer": "standard_tokenizer",
                "filter": [
                    "lowercase",
                    "stop-english_filter",
                ]
             },
            },
            "filter": {
              "metaphone_filter": {
                "type": "phonetic",
                "encoder": "metaphone",
                "replace": True
              },
              "metaphone_filter_no_replacement": {
                "type": "phonetic",
                "encoder": "metaphone",
                "replace": False
              },
              "stop-english_filter": {
                    "type": "stop",
                    "stopwords": "_english_"
              },
              "stemmer-porter2_filter": {
                    "type": "stemmer",
                    "language": "porter2"
              },
            },
            "tokenizer": {
                "standard_tokenizer": {
                    "type": "standard"
                }
            }
          }
        }
    }

# %%
def get_mappings():
    return {
        "properties": {
            "article_id": {
                "type": "keyword"
            },
            "text": {
                "type": "text",
                "analyzer": "stop-english_standard_analyzer",
                "copy_to": ["text_phonemes","text_phonemes_no_replacement"]
            },
            "title": {
                "type": "text",
                "analyzer": "stop-english_standard_analyzer",
            },
            "text_phonemes": {
                "type": "text",
                "analyzer": "phonetic_analyzer",
            },
            "text_phonemes_no_replacement": {
                "type": "text",
                "analyzer": "phonetic_analyzer_no_replacement",
            },
        }
    }

# %%
def document_mapping_func(doc: Dict[str, Any])->Dict[str, Any]:
    return {
        'article_id': doc['uuid'],
        'text': doc['text'],
        'title': doc['title'],
    }

# %% [markdown]
# ### Load datasets

# %%
DOCUMENTS_SQUAD, QUESTIONS_SQUAD = ExperimentUtil.load_dataset('squad_10k')
DOCUMENTS_SWIFT, QUESTIONS_SWIFT = ExperimentUtil.load_dataset('swift_ui')

# %% [markdown]
# ### Query

# %%
def phonemes_query(query, fields = ["text_phonemes","text^2.0", "title"], query_type = 'cross_fields', index=INDEX, index_name=INDEX_NAME, limit = 10):
    res = INDEX.elastic_connector.search(
        index=INDEX_NAME, 
        size=limit, 
        query={
            "multi_match" : {
              "query":    query, 
              "fields": fields,
              "type": query_type
            }
        },
        search_type='dfs_query_then_fetch'
    )
    results =  [(hit["_source"]) for hit in res['hits']['hits']]
    return results

# %% [markdown]
# ### Experiment

# %%
def test_phonemes_impact(documents, questions, index = INDEX_NAME, query_fuc = phonemes_query):
    fields_ls = []
    types_ls = []
    hits_top_10_ls = []
    hits_top_5_ls = []
    hits_top_3_ls = []
    hits_top_1_ls = []
    
    fields_range=[
        ["text"],
        ["text_phonemes"],
        ["text_phonemes_no_replacement"],
        ["title"],
        ["text","text_phonemes"],
        ["text","text_phonemes_no_replacement"],
        ["text_phonemes","text", "title"],
        ["text_phonemes","text^2.0", "title"],
        ["text_phonemes_no_replacement","text", "title"],
        ["text_phonemes_no_replacement","text^2.0", "title"],
    ]
    
    types_range = ['cross_fields','most_fields', 'best_fields']
    
    INDEX.delete_index()
    INDEX.create_index(get_mappings(), get_settings())
    INDEX.index_all_docs(documents, document_mapping_func)
    
    for fields in tqdm(fields_range):
        for query_type in tqdm(types_range):

            fields_ls.append(str(fields))
            types_ls.append(query_type)
            time.sleep(1)
            all_hits = ExperimentUtil.validate(
                index,
                questions,
                lambda query,limit: query_fuc(
                    query=query,
                    fields=fields,
                    query_type=query_type,
                    limit=limit
                )
            )
            hits_10, hits_5, hit_3, hits_1 = all_hits['hits@10'], all_hits['hits@5'], all_hits['hits@3'], all_hits['hits@1']
            hits_top_10_ls.append(hits_10)
            hits_top_5_ls.append(hits_5)
            hits_top_3_ls.append(hit_3)
            hits_top_1_ls.append(hits_1)

    return pd.DataFrame.from_dict({
        'fields':fields_ls,
        'query_type': types_ls,
        'hits@10':hits_top_10_ls,
        'hits@5':hits_top_5_ls,
        'hits@3':hits_top_3_ls,
        'hits@1':hits_top_1_ls
    })

# %%
# phonemes_swift_df = test_phonemes_impact(DOCUMENTS_SWIFT, QUESTIONS_SWIFT)

# %%
# phonemes_swift_df.to_csv('results/phonemes_swift.csv')

# %%
# phonemes_squad_df = test_phonemes_impact(DOCUMENTS_SQUAD, QUESTIONS_SQUAD)

# %%
# phonemes_squad_df.to_csv('results/phonemes_squad.csv')

# %% [markdown]
# ### Explore results

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-47-1390d13c0cdd>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
phonemes_swift_df_10 = phonemes_swift_df.sort_values(['hits@10'], ascending=False)
phonemes_swift_df_10 = phonemes_swift_df_10.style.set_caption("SWIFT_UI - performance of phonetic analyzer sorted by hits@10")
phonemes_swift_df_10
# Out:
# <style type="text/css">
# </style>
# <table id="T_da5ed_">
#   <caption>SWIFT_UI - performance of phonetic analyzer sorted by hits@10</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fields</th>
#       <th class="col_heading level0 col1" >query_type</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da5ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da5ed_row0_col0" class="data row0 col0" >['text']</td>
#       <td id="T_da5ed_row0_col1" class="data row0 col1" >cross_fields</td>
#       <td id="T_da5ed_row0_col2" class="data row0 col2" >0.940217</td>
#       <td id="T_da5ed_row0_col3" class="data row0 col3" >0.864130</td>
#       <td id="T_da5ed_row0_col4" class="data row0 col4" >0.804348</td>
#       <td id="T_da5ed_row0_col5" class="data row0 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da5ed_row1_col0" class="data row1 col0" >['text']</td>
#       <td id="T_da5ed_row1_col1" class="data row1 col1" >most_fields</td>
#       <td id="T_da5ed_row1_col2" class="data row1 col2" >0.940217</td>
#       <td id="T_da5ed_row1_col3" class="data row1 col3" >0.864130</td>
#       <td id="T_da5ed_row1_col4" class="data row1 col4" >0.804348</td>
#       <td id="T_da5ed_row1_col5" class="data row1 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row2" class="row_heading level0 row2" >27</th>
#       <td id="T_da5ed_row2_col0" class="data row2 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_da5ed_row2_col1" class="data row2 col1" >cross_fields</td>
#       <td id="T_da5ed_row2_col2" class="data row2 col2" >0.940217</td>
#       <td id="T_da5ed_row2_col3" class="data row2 col3" >0.869565</td>
#       <td id="T_da5ed_row2_col4" class="data row2 col4" >0.804348</td>
#       <td id="T_da5ed_row2_col5" class="data row2 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_da5ed_row3_col0" class="data row3 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_da5ed_row3_col1" class="data row3 col1" >best_fields</td>
#       <td id="T_da5ed_row3_col2" class="data row3 col2" >0.940217</td>
#       <td id="T_da5ed_row3_col3" class="data row3 col3" >0.864130</td>
#       <td id="T_da5ed_row3_col4" class="data row3 col4" >0.798913</td>
#       <td id="T_da5ed_row3_col5" class="data row3 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row4" class="row_heading level0 row4" >22</th>
#       <td id="T_da5ed_row4_col0" class="data row4 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_da5ed_row4_col1" class="data row4 col1" >most_fields</td>
#       <td id="T_da5ed_row4_col2" class="data row4 col2" >0.940217</td>
#       <td id="T_da5ed_row4_col3" class="data row4 col3" >0.885870</td>
#       <td id="T_da5ed_row4_col4" class="data row4 col4" >0.798913</td>
#       <td id="T_da5ed_row4_col5" class="data row4 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_da5ed_row5_col0" class="data row5 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_da5ed_row5_col1" class="data row5 col1" >cross_fields</td>
#       <td id="T_da5ed_row5_col2" class="data row5 col2" >0.940217</td>
#       <td id="T_da5ed_row5_col3" class="data row5 col3" >0.864130</td>
#       <td id="T_da5ed_row5_col4" class="data row5 col4" >0.798913</td>
#       <td id="T_da5ed_row5_col5" class="data row5 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row6" class="row_heading level0 row6" >29</th>
#       <td id="T_da5ed_row6_col0" class="data row6 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_da5ed_row6_col1" class="data row6 col1" >best_fields</td>
#       <td id="T_da5ed_row6_col2" class="data row6 col2" >0.940217</td>
#       <td id="T_da5ed_row6_col3" class="data row6 col3" >0.869565</td>
#       <td id="T_da5ed_row6_col4" class="data row6 col4" >0.804348</td>
#       <td id="T_da5ed_row6_col5" class="data row6 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_da5ed_row7_col0" class="data row7 col0" >['text']</td>
#       <td id="T_da5ed_row7_col1" class="data row7 col1" >best_fields</td>
#       <td id="T_da5ed_row7_col2" class="data row7 col2" >0.940217</td>
#       <td id="T_da5ed_row7_col3" class="data row7 col3" >0.864130</td>
#       <td id="T_da5ed_row7_col4" class="data row7 col4" >0.804348</td>
#       <td id="T_da5ed_row7_col5" class="data row7 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row8" class="row_heading level0 row8" >19</th>
#       <td id="T_da5ed_row8_col0" class="data row8 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_da5ed_row8_col1" class="data row8 col1" >most_fields</td>
#       <td id="T_da5ed_row8_col2" class="data row8 col2" >0.934783</td>
#       <td id="T_da5ed_row8_col3" class="data row8 col3" >0.875000</td>
#       <td id="T_da5ed_row8_col4" class="data row8 col4" >0.798913</td>
#       <td id="T_da5ed_row8_col5" class="data row8 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row9" class="row_heading level0 row9" >13</th>
#       <td id="T_da5ed_row9_col0" class="data row9 col0" >['text', 'text_phonemes']</td>
#       <td id="T_da5ed_row9_col1" class="data row9 col1" >most_fields</td>
#       <td id="T_da5ed_row9_col2" class="data row9 col2" >0.929348</td>
#       <td id="T_da5ed_row9_col3" class="data row9 col3" >0.875000</td>
#       <td id="T_da5ed_row9_col4" class="data row9 col4" >0.804348</td>
#       <td id="T_da5ed_row9_col5" class="data row9 col5" >0.614130</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row10" class="row_heading level0 row10" >18</th>
#       <td id="T_da5ed_row10_col0" class="data row10 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_da5ed_row10_col1" class="data row10 col1" >cross_fields</td>
#       <td id="T_da5ed_row10_col2" class="data row10 col2" >0.923913</td>
#       <td id="T_da5ed_row10_col3" class="data row10 col3" >0.875000</td>
#       <td id="T_da5ed_row10_col4" class="data row10 col4" >0.809783</td>
#       <td id="T_da5ed_row10_col5" class="data row10 col5" >0.586957</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row11" class="row_heading level0 row11" >28</th>
#       <td id="T_da5ed_row11_col0" class="data row11 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_da5ed_row11_col1" class="data row11 col1" >most_fields</td>
#       <td id="T_da5ed_row11_col2" class="data row11 col2" >0.923913</td>
#       <td id="T_da5ed_row11_col3" class="data row11 col3" >0.858696</td>
#       <td id="T_da5ed_row11_col4" class="data row11 col4" >0.798913</td>
#       <td id="T_da5ed_row11_col5" class="data row11 col5" >0.597826</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_da5ed_row12_col0" class="data row12 col0" >['text', 'text_phonemes']</td>
#       <td id="T_da5ed_row12_col1" class="data row12 col1" >cross_fields</td>
#       <td id="T_da5ed_row12_col2" class="data row12 col2" >0.923913</td>
#       <td id="T_da5ed_row12_col3" class="data row12 col3" >0.869565</td>
#       <td id="T_da5ed_row12_col4" class="data row12 col4" >0.804348</td>
#       <td id="T_da5ed_row12_col5" class="data row12 col5" >0.581522</td>
#     </tr>
#     <tr>
#       <th id="T_da5ed_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_da5ed_row13_col0" class="data row13 col0" >['text', 'text_phonemes']</td>
#       <td id="T_da5ed_row13_col1" class="data row13 col1" >best_fields</td>
#       <td id=

# %%
phonemes_swift_df_5 = phonemes_swift_df.sort_values(['hits@5'], ascending=False)
phonemes_swift_df_5 = phonemes_swift_df_5.style.set_caption("SWIFT_UI - performance of phonetic analyzer sorted by hits@5")
phonemes_swift_df_5
# Out:
# <style type="text/css">
# </style>
# <table id="T_37fcd_">
#   <caption>SWIFT_UI - performance of phonetic analyzer sorted by hits@5</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fields</th>
#       <th class="col_heading level0 col1" >query_type</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37fcd_level0_row0" class="row_heading level0 row0" >22</th>
#       <td id="T_37fcd_row0_col0" class="data row0 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_37fcd_row0_col1" class="data row0 col1" >most_fields</td>
#       <td id="T_37fcd_row0_col2" class="data row0 col2" >0.940217</td>
#       <td id="T_37fcd_row0_col3" class="data row0 col3" >0.885870</td>
#       <td id="T_37fcd_row0_col4" class="data row0 col4" >0.798913</td>
#       <td id="T_37fcd_row0_col5" class="data row0 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_37fcd_row1_col0" class="data row1 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_37fcd_row1_col1" class="data row1 col1" >most_fields</td>
#       <td id="T_37fcd_row1_col2" class="data row1 col2" >0.934783</td>
#       <td id="T_37fcd_row1_col3" class="data row1 col3" >0.875000</td>
#       <td id="T_37fcd_row1_col4" class="data row1 col4" >0.798913</td>
#       <td id="T_37fcd_row1_col5" class="data row1 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row2" class="row_heading level0 row2" >18</th>
#       <td id="T_37fcd_row2_col0" class="data row2 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_37fcd_row2_col1" class="data row2 col1" >cross_fields</td>
#       <td id="T_37fcd_row2_col2" class="data row2 col2" >0.923913</td>
#       <td id="T_37fcd_row2_col3" class="data row2 col3" >0.875000</td>
#       <td id="T_37fcd_row2_col4" class="data row2 col4" >0.809783</td>
#       <td id="T_37fcd_row2_col5" class="data row2 col5" >0.586957</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_37fcd_row3_col0" class="data row3 col0" >['text', 'text_phonemes']</td>
#       <td id="T_37fcd_row3_col1" class="data row3 col1" >most_fields</td>
#       <td id="T_37fcd_row3_col2" class="data row3 col2" >0.929348</td>
#       <td id="T_37fcd_row3_col3" class="data row3 col3" >0.875000</td>
#       <td id="T_37fcd_row3_col4" class="data row3 col4" >0.804348</td>
#       <td id="T_37fcd_row3_col5" class="data row3 col5" >0.614130</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row4" class="row_heading level0 row4" >29</th>
#       <td id="T_37fcd_row4_col0" class="data row4 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_37fcd_row4_col1" class="data row4 col1" >best_fields</td>
#       <td id="T_37fcd_row4_col2" class="data row4 col2" >0.940217</td>
#       <td id="T_37fcd_row4_col3" class="data row4 col3" >0.869565</td>
#       <td id="T_37fcd_row4_col4" class="data row4 col4" >0.804348</td>
#       <td id="T_37fcd_row4_col5" class="data row4 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_37fcd_row5_col0" class="data row5 col0" >['text', 'text_phonemes']</td>
#       <td id="T_37fcd_row5_col1" class="data row5 col1" >cross_fields</td>
#       <td id="T_37fcd_row5_col2" class="data row5 col2" >0.923913</td>
#       <td id="T_37fcd_row5_col3" class="data row5 col3" >0.869565</td>
#       <td id="T_37fcd_row5_col4" class="data row5 col4" >0.804348</td>
#       <td id="T_37fcd_row5_col5" class="data row5 col5" >0.581522</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_37fcd_row6_col0" class="data row6 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_37fcd_row6_col1" class="data row6 col1" >cross_fields</td>
#       <td id="T_37fcd_row6_col2" class="data row6 col2" >0.940217</td>
#       <td id="T_37fcd_row6_col3" class="data row6 col3" >0.869565</td>
#       <td id="T_37fcd_row6_col4" class="data row6 col4" >0.804348</td>
#       <td id="T_37fcd_row6_col5" class="data row6 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row7" class="row_heading level0 row7" >20</th>
#       <td id="T_37fcd_row7_col0" class="data row7 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_37fcd_row7_col1" class="data row7 col1" >best_fields</td>
#       <td id="T_37fcd_row7_col2" class="data row7 col2" >0.923913</td>
#       <td id="T_37fcd_row7_col3" class="data row7 col3" >0.869565</td>
#       <td id="T_37fcd_row7_col4" class="data row7 col4" >0.804348</td>
#       <td id="T_37fcd_row7_col5" class="data row7 col5" >0.581522</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row8" class="row_heading level0 row8" >14</th>
#       <td id="T_37fcd_row8_col0" class="data row8 col0" >['text', 'text_phonemes']</td>
#       <td id="T_37fcd_row8_col1" class="data row8 col1" >best_fields</td>
#       <td id="T_37fcd_row8_col2" class="data row8 col2" >0.923913</td>
#       <td id="T_37fcd_row8_col3" class="data row8 col3" >0.869565</td>
#       <td id="T_37fcd_row8_col4" class="data row8 col4" >0.804348</td>
#       <td id="T_37fcd_row8_col5" class="data row8 col5" >0.581522</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row9" class="row_heading level0 row9" >23</th>
#       <td id="T_37fcd_row9_col0" class="data row9 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_37fcd_row9_col1" class="data row9 col1" >best_fields</td>
#       <td id="T_37fcd_row9_col2" class="data row9 col2" >0.940217</td>
#       <td id="T_37fcd_row9_col3" class="data row9 col3" >0.864130</td>
#       <td id="T_37fcd_row9_col4" class="data row9 col4" >0.798913</td>
#       <td id="T_37fcd_row9_col5" class="data row9 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row10" class="row_heading level0 row10" >21</th>
#       <td id="T_37fcd_row10_col0" class="data row10 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_37fcd_row10_col1" class="data row10 col1" >cross_fields</td>
#       <td id="T_37fcd_row10_col2" class="data row10 col2" >0.940217</td>
#       <td id="T_37fcd_row10_col3" class="data row10 col3" >0.864130</td>
#       <td id="T_37fcd_row10_col4" class="data row10 col4" >0.798913</td>
#       <td id="T_37fcd_row10_col5" class="data row10 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_37fcd_row11_col0" class="data row11 col0" >['text']</td>
#       <td id="T_37fcd_row11_col1" class="data row11 col1" >most_fields</td>
#       <td id="T_37fcd_row11_col2" class="data row11 col2" >0.940217</td>
#       <td id="T_37fcd_row11_col3" class="data row11 col3" >0.864130</td>
#       <td id="T_37fcd_row11_col4" class="data row11 col4" >0.804348</td>
#       <td id="T_37fcd_row11_col5" class="data row11 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row12" class="row_heading level0 row12" >0</th>
#       <td id="T_37fcd_row12_col0" class="data row12 col0" >['text']</td>
#       <td id="T_37fcd_row12_col1" class="data row12 col1" >cross_fields</td>
#       <td id="T_37fcd_row12_col2" class="data row12 col2" >0.940217</td>
#       <td id="T_37fcd_row12_col3" class="data row12 col3" >0.864130</td>
#       <td id="T_37fcd_row12_col4" class="data row12 col4" >0.804348</td>
#       <td id="T_37fcd_row12_col5" class="data row12 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_37fcd_level0_row13" class="row_heading level0 row13" >2</th>
#       <td id="T_37fcd_row13_col0" class="data row13 col0" >['text']</td>
#       <td id="T_37fcd_row13_col1" class="data row13 col1" >best_fields</td>
#       <td id="T_37fcd_row13_col2"

# %%
phonemes_squad_df_10 = phonemes_squad_df.sort_values(['hits@10'], ascending=False)
phonemes_squad_df_10 = phonemes_squad_df_10.style.set_caption("SUQAD 10k - performance of phonetic analyzer sorted by hits@10")
phonemes_squad_df_10
# Out:
# <style type="text/css">
# </style>
# <table id="T_15e95_">
#   <caption>SUQAD 10k - performance of phonetic analyzer sorted by hits@10</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fields</th>
#       <th class="col_heading level0 col1" >query_type</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15e95_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_15e95_row0_col0" class="data row0 col0" >['text', 'text_phonemes']</td>
#       <td id="T_15e95_row0_col1" class="data row0 col1" >most_fields</td>
#       <td id="T_15e95_row0_col2" class="data row0 col2" >0.923000</td>
#       <td id="T_15e95_row0_col3" class="data row0 col3" >0.890000</td>
#       <td id="T_15e95_row0_col4" class="data row0 col4" >0.862000</td>
#       <td id="T_15e95_row0_col5" class="data row0 col5" >0.739000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row1" class="row_heading level0 row1" >28</th>
#       <td id="T_15e95_row1_col0" class="data row1 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_15e95_row1_col1" class="data row1 col1" >most_fields</td>
#       <td id="T_15e95_row1_col2" class="data row1 col2" >0.922000</td>
#       <td id="T_15e95_row1_col3" class="data row1 col3" >0.889000</td>
#       <td id="T_15e95_row1_col4" class="data row1 col4" >0.858000</td>
#       <td id="T_15e95_row1_col5" class="data row1 col5" >0.739000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_15e95_row2_col0" class="data row2 col0" >['text_phonemes_no_replacement', 'text', 'title']</td>
#       <td id="T_15e95_row2_col1" class="data row2 col1" >most_fields</td>
#       <td id="T_15e95_row2_col2" class="data row2 col2" >0.922000</td>
#       <td id="T_15e95_row2_col3" class="data row2 col3" >0.890000</td>
#       <td id="T_15e95_row2_col4" class="data row2 col4" >0.860000</td>
#       <td id="T_15e95_row2_col5" class="data row2 col5" >0.738000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_15e95_row3_col0" class="data row3 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_15e95_row3_col1" class="data row3 col1" >most_fields</td>
#       <td id="T_15e95_row3_col2" class="data row3 col2" >0.922000</td>
#       <td id="T_15e95_row3_col3" class="data row3 col3" >0.889000</td>
#       <td id="T_15e95_row3_col4" class="data row3 col4" >0.853000</td>
#       <td id="T_15e95_row3_col5" class="data row3 col5" >0.732000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_15e95_row4_col0" class="data row4 col0" >['text', 'text_phonemes_no_replacement']</td>
#       <td id="T_15e95_row4_col1" class="data row4 col1" >most_fields</td>
#       <td id="T_15e95_row4_col2" class="data row4 col2" >0.920000</td>
#       <td id="T_15e95_row4_col3" class="data row4 col3" >0.889000</td>
#       <td id="T_15e95_row4_col4" class="data row4 col4" >0.857000</td>
#       <td id="T_15e95_row4_col5" class="data row4 col5" >0.737000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row5" class="row_heading level0 row5" >19</th>
#       <td id="T_15e95_row5_col0" class="data row5 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_15e95_row5_col1" class="data row5 col1" >most_fields</td>
#       <td id="T_15e95_row5_col2" class="data row5 col2" >0.919000</td>
#       <td id="T_15e95_row5_col3" class="data row5 col3" >0.890000</td>
#       <td id="T_15e95_row5_col4" class="data row5 col4" >0.856000</td>
#       <td id="T_15e95_row5_col5" class="data row5 col5" >0.733000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_15e95_row6_col0" class="data row6 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_15e95_row6_col1" class="data row6 col1" >cross_fields</td>
#       <td id="T_15e95_row6_col2" class="data row6 col2" >0.917000</td>
#       <td id="T_15e95_row6_col3" class="data row6 col3" >0.878000</td>
#       <td id="T_15e95_row6_col4" class="data row6 col4" >0.843000</td>
#       <td id="T_15e95_row6_col5" class="data row6 col5" >0.720000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row7" class="row_heading level0 row7" >29</th>
#       <td id="T_15e95_row7_col0" class="data row7 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_15e95_row7_col1" class="data row7 col1" >best_fields</td>
#       <td id="T_15e95_row7_col2" class="data row7 col2" >0.913000</td>
#       <td id="T_15e95_row7_col3" class="data row7 col3" >0.877000</td>
#       <td id="T_15e95_row7_col4" class="data row7 col4" >0.843000</td>
#       <td id="T_15e95_row7_col5" class="data row7 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_15e95_row8_col0" class="data row8 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_15e95_row8_col1" class="data row8 col1" >cross_fields</td>
#       <td id="T_15e95_row8_col2" class="data row8 col2" >0.913000</td>
#       <td id="T_15e95_row8_col3" class="data row8 col3" >0.872000</td>
#       <td id="T_15e95_row8_col4" class="data row8 col4" >0.838000</td>
#       <td id="T_15e95_row8_col5" class="data row8 col5" >0.719000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row9" class="row_heading level0 row9" >18</th>
#       <td id="T_15e95_row9_col0" class="data row9 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_15e95_row9_col1" class="data row9 col1" >cross_fields</td>
#       <td id="T_15e95_row9_col2" class="data row9 col2" >0.912000</td>
#       <td id="T_15e95_row9_col3" class="data row9 col3" >0.881000</td>
#       <td id="T_15e95_row9_col4" class="data row9 col4" >0.845000</td>
#       <td id="T_15e95_row9_col5" class="data row9 col5" >0.728000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row10" class="row_heading level0 row10" >23</th>
#       <td id="T_15e95_row10_col0" class="data row10 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_15e95_row10_col1" class="data row10 col1" >best_fields</td>
#       <td id="T_15e95_row10_col2" class="data row10 col2" >0.908000</td>
#       <td id="T_15e95_row10_col3" class="data row10 col3" >0.869000</td>
#       <td id="T_15e95_row10_col4" class="data row10 col4" >0.836000</td>
#       <td id="T_15e95_row10_col5" class="data row10 col5" >0.716000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row11" class="row_heading level0 row11" >20</th>
#       <td id="T_15e95_row11_col0" class="data row11 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_15e95_row11_col1" class="data row11 col1" >best_fields</td>
#       <td id="T_15e95_row11_col2" class="data row11 col2" >0.908000</td>
#       <td id="T_15e95_row11_col3" class="data row11 col3" >0.878000</td>
#       <td id="T_15e95_row11_col4" class="data row11 col4" >0.843000</td>
#       <td id="T_15e95_row11_col5" class="data row11 col5" >0.721000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_15e95_row12_col0" class="data row12 col0" >['text', 'text_phonemes']</td>
#       <td id="T_15e95_row12_col1" class="data row12 col1" >cross_fields</td>
#       <td id="T_15e95_row12_col2" class="data row12 col2" >0.908000</td>
#       <td id="T_15e95_row12_col3" class="data row12 col3" >0.878000</td>
#       <td id="T_15e95_row12_col4" class="data row12 col4" >0.843000</td>
#       <td id="T_15e95_row12_col5" class="data row12 col5" >0.721000</td>
#     </tr>
#     <tr>
#       <th id="T_15e95_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_15e95_row13_col0" class="data row13 col0" >['text', 'text_pho

# %%
phonemes_squad_df_5 = phonemes_squad_df.sort_values(['hits@5'], ascending=False)
phonemes_squad_df_5 = phonemes_squad_df_5.style.set_caption("SUQAD 10k - performance of phonetic analyzer sorted by hits@5")
phonemes_squad_df_5
# Out:
# <style type="text/css">
# </style>
# <table id="T_80541_">
#   <caption>SUQAD 10k - performance of phonetic analyzer sorted by hits@5</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fields</th>
#       <th class="col_heading level0 col1" >query_type</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80541_level0_row0" class="row_heading level0 row0" >25</th>
#       <td id="T_80541_row0_col0" class="data row0 col0" >['text_phonemes_no_replacement', 'text', 'title']</td>
#       <td id="T_80541_row0_col1" class="data row0 col1" >most_fields</td>
#       <td id="T_80541_row0_col2" class="data row0 col2" >0.922000</td>
#       <td id="T_80541_row0_col3" class="data row0 col3" >0.890000</td>
#       <td id="T_80541_row0_col4" class="data row0 col4" >0.860000</td>
#       <td id="T_80541_row0_col5" class="data row0 col5" >0.738000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_80541_row1_col0" class="data row1 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_80541_row1_col1" class="data row1 col1" >most_fields</td>
#       <td id="T_80541_row1_col2" class="data row1 col2" >0.919000</td>
#       <td id="T_80541_row1_col3" class="data row1 col3" >0.890000</td>
#       <td id="T_80541_row1_col4" class="data row1 col4" >0.856000</td>
#       <td id="T_80541_row1_col5" class="data row1 col5" >0.733000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_80541_row2_col0" class="data row2 col0" >['text', 'text_phonemes']</td>
#       <td id="T_80541_row2_col1" class="data row2 col1" >most_fields</td>
#       <td id="T_80541_row2_col2" class="data row2 col2" >0.923000</td>
#       <td id="T_80541_row2_col3" class="data row2 col3" >0.890000</td>
#       <td id="T_80541_row2_col4" class="data row2 col4" >0.862000</td>
#       <td id="T_80541_row2_col5" class="data row2 col5" >0.739000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row3" class="row_heading level0 row3" >28</th>
#       <td id="T_80541_row3_col0" class="data row3 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_80541_row3_col1" class="data row3 col1" >most_fields</td>
#       <td id="T_80541_row3_col2" class="data row3 col2" >0.922000</td>
#       <td id="T_80541_row3_col3" class="data row3 col3" >0.889000</td>
#       <td id="T_80541_row3_col4" class="data row3 col4" >0.858000</td>
#       <td id="T_80541_row3_col5" class="data row3 col5" >0.739000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row4" class="row_heading level0 row4" >22</th>
#       <td id="T_80541_row4_col0" class="data row4 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_80541_row4_col1" class="data row4 col1" >most_fields</td>
#       <td id="T_80541_row4_col2" class="data row4 col2" >0.922000</td>
#       <td id="T_80541_row4_col3" class="data row4 col3" >0.889000</td>
#       <td id="T_80541_row4_col4" class="data row4 col4" >0.853000</td>
#       <td id="T_80541_row4_col5" class="data row4 col5" >0.732000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_80541_row5_col0" class="data row5 col0" >['text', 'text_phonemes_no_replacement']</td>
#       <td id="T_80541_row5_col1" class="data row5 col1" >most_fields</td>
#       <td id="T_80541_row5_col2" class="data row5 col2" >0.920000</td>
#       <td id="T_80541_row5_col3" class="data row5 col3" >0.889000</td>
#       <td id="T_80541_row5_col4" class="data row5 col4" >0.857000</td>
#       <td id="T_80541_row5_col5" class="data row5 col5" >0.737000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row6" class="row_heading level0 row6" >18</th>
#       <td id="T_80541_row6_col0" class="data row6 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_80541_row6_col1" class="data row6 col1" >cross_fields</td>
#       <td id="T_80541_row6_col2" class="data row6 col2" >0.912000</td>
#       <td id="T_80541_row6_col3" class="data row6 col3" >0.881000</td>
#       <td id="T_80541_row6_col4" class="data row6 col4" >0.845000</td>
#       <td id="T_80541_row6_col5" class="data row6 col5" >0.728000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row7" class="row_heading level0 row7" >27</th>
#       <td id="T_80541_row7_col0" class="data row7 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_80541_row7_col1" class="data row7 col1" >cross_fields</td>
#       <td id="T_80541_row7_col2" class="data row7 col2" >0.917000</td>
#       <td id="T_80541_row7_col3" class="data row7 col3" >0.878000</td>
#       <td id="T_80541_row7_col4" class="data row7 col4" >0.843000</td>
#       <td id="T_80541_row7_col5" class="data row7 col5" >0.720000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row8" class="row_heading level0 row8" >20</th>
#       <td id="T_80541_row8_col0" class="data row8 col0" >['text_phonemes', 'text', 'title']</td>
#       <td id="T_80541_row8_col1" class="data row8 col1" >best_fields</td>
#       <td id="T_80541_row8_col2" class="data row8 col2" >0.908000</td>
#       <td id="T_80541_row8_col3" class="data row8 col3" >0.878000</td>
#       <td id="T_80541_row8_col4" class="data row8 col4" >0.843000</td>
#       <td id="T_80541_row8_col5" class="data row8 col5" >0.721000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_80541_row9_col0" class="data row9 col0" >['text', 'text_phonemes']</td>
#       <td id="T_80541_row9_col1" class="data row9 col1" >cross_fields</td>
#       <td id="T_80541_row9_col2" class="data row9 col2" >0.908000</td>
#       <td id="T_80541_row9_col3" class="data row9 col3" >0.878000</td>
#       <td id="T_80541_row9_col4" class="data row9 col4" >0.843000</td>
#       <td id="T_80541_row9_col5" class="data row9 col5" >0.721000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row10" class="row_heading level0 row10" >14</th>
#       <td id="T_80541_row10_col0" class="data row10 col0" >['text', 'text_phonemes']</td>
#       <td id="T_80541_row10_col1" class="data row10 col1" >best_fields</td>
#       <td id="T_80541_row10_col2" class="data row10 col2" >0.908000</td>
#       <td id="T_80541_row10_col3" class="data row10 col3" >0.878000</td>
#       <td id="T_80541_row10_col4" class="data row10 col4" >0.843000</td>
#       <td id="T_80541_row10_col5" class="data row10 col5" >0.721000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row11" class="row_heading level0 row11" >29</th>
#       <td id="T_80541_row11_col0" class="data row11 col0" >['text_phonemes_no_replacement', 'text^2.0', 'title']</td>
#       <td id="T_80541_row11_col1" class="data row11 col1" >best_fields</td>
#       <td id="T_80541_row11_col2" class="data row11 col2" >0.913000</td>
#       <td id="T_80541_row11_col3" class="data row11 col3" >0.877000</td>
#       <td id="T_80541_row11_col4" class="data row11 col4" >0.843000</td>
#       <td id="T_80541_row11_col5" class="data row11 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row12" class="row_heading level0 row12" >21</th>
#       <td id="T_80541_row12_col0" class="data row12 col0" >['text_phonemes', 'text^2.0', 'title']</td>
#       <td id="T_80541_row12_col1" class="data row12 col1" >cross_fields</td>
#       <td id="T_80541_row12_col2" class="data row12 col2" >0.913000</td>
#       <td id="T_80541_row12_col3" class="data row12 col3" >0.872000</td>
#       <td id="T_80541_row12_col4" class="data row12 col4" >0.838000</td>
#       <td id="T_80541_row12_col5" class="data row12 col5" >0.719000</td>
#     </tr>
#     <tr>
#       <th id="T_80541_level0_row13" class="row_heading level0 row13" >23</th>
#       <td id="T_80541_row13_col0" class="data row13 col0" >['text_phonemes', 'text^2.0', 't

# %% [markdown]
# ### See how phonetic analyzer works

# %%
ANALYZER = AnalyzerUtil(INDEX_NAME)
SAMPLE_TEXT = 'Tom Hanks is a good actor as he loves playing'

# %%
ANALYZER.analyze(analyzer='phonetic_analyzer', text=SAMPLE_TEXT)
# Out:
# ['TM', 'HNKS', 'IS', 'A', 'KT', 'AKTR', 'AS', 'H', 'LFS', 'PLYN']

# %%
ANALYZER.analyze(analyzer='phonetic_analyzer_no_replacement', text=SAMPLE_TEXT)
# Out:
# ['TM',
#  'tom',
#  'HNKS',
#  'hanks',
#  'IS',
#  'is',
#  'A',
#  'a',
#  'KT',
#  'good',
#  'AKTR',
#  'actor',
#  'AS',
#  'as',
#  'H',
#  'he',
#  'LFS',
#  'loves',
#  'PLYN',
#  'playing']
