# %% [markdown]
# ### Imports

# %%
import time
import pandas as pd
from typing import Callable, Union, List, Dict, Any, Tuple
from tqdm.notebook import tqdm

# %%
from index_utils import IndexUtil
from scoring_utils import ScoringUtil
from experiment_utils import ExperimentUtil

# %% [markdown]
# ### Prepare index/mappings/settings

# %%
INDEX_NAME = 'index_similarity'

# %%
INDEX = IndexUtil(INDEX_NAME)

# %%
def get_index_mappings(analyzer:str = 'stop-english_standard_analyzer'):
    return {
        "properties": {
            "article_id": {
                "type": "keyword"
            },
            "text": {
                "type": "text",
                "analyzer": analyzer
            },
        }
    }

# %%
def get_settings(similarity:str = 'bm25'):
    settings = IndexUtil.get_default_settings()
    IndexUtil.set_shards_in_settings(settings)
    ScoringUtil.set_similarity(settings, similarity)
    return settings

# %%
def document_mapping_func(doc: Dict[str, Any])->Dict[str, Any]:
    return {
        'article_id': doc['uuid'],
        'text': doc['text'],
    }

# %% [markdown]
# ### Load datasets

# %%
DOCUMENTS_SQUAD, QUESTIONS_SQUAD = ExperimentUtil.load_dataset('squad_10k')
DOCUMENTS_SWIFT, QUESTIONS_SWIFT = ExperimentUtil.load_dataset('swift_ui')

# %% [markdown]
# ### Experiment

# %%
def test_similarity_functions(documents, questions, index = INDEX_NAME, query_fuc = INDEX.default_query):
    similarity_ls = []
    analyzers_ls = []
    hits_top_10_ls = []
    hits_top_5_ls = []
    hits_top_3_ls = []
    hits_top_1_ls = []
    similarity_range=['bm25','dfr','dfi','ib','lm_d','lm_jm','tfidf']
    analyzers_range = ['stop-english_standard_analyzer','stemmer-porter2_standard_analyzer']
    for similarity in tqdm(similarity_range):
        for analyzer in analyzers_range:
            INDEX.delete_index()
            INDEX.create_index(get_index_mappings(analyzer), get_settings(similarity))
            INDEX.index_all_docs(documents, document_mapping_func)
            similarity_ls.append(similarity)
            analyzers_ls.append(analyzer)
            time.sleep(1)
            all_hits = ExperimentUtil.validate(index, questions, query_fuc)
            hits_10, hits_5, hit_3, hits_1 = all_hits['hits@10'], all_hits['hits@5'], all_hits['hits@3'], all_hits['hits@1']
            hits_top_10_ls.append(hits_10)
            hits_top_5_ls.append(hits_5)
            hits_top_3_ls.append(hit_3)
            hits_top_1_ls.append(hits_1)
    return pd.DataFrame.from_dict({
        'similarity_function':similarity_ls,
        'analyzer': analyzers_ls,
        'hits@10':hits_top_10_ls,
        'hits@5':hits_top_5_ls,
        'hits@3':hits_top_3_ls,
        'hits@1':hits_top_1_ls
    })

# %%
# similarity_swift_df = test_similarity_functions(DOCUMENTS_SWIFT, QUESTIONS_SWIFT)

# %%
# similarity_squad_df = test_similarity_functions(DOCUMENTS_SQUAD, QUESTIONS_SQUAD)

# %%
# similarity_swift_df.to_csv('results/similarity_functions_swift.csv')

# %%
# similarity_squad_df.to_csv('results/similarity_functions_squad.csv')

# %% [markdown]
# ### Explore results

# %% [markdown]
# #### SWIFT_UI

# %%
similarity_swift_df_10 = similarity_swift_df.sort_values(['analyzer','hits@10'], ascending=False)
similarity_swift_df_10 = similarity_swift_df_10.style.set_caption("SWIFT_UI - impact of similarity function by hits@10")
similarity_swift_df_10
# Out:
# <style type="text/css">
# </style>
# <table id="T_08c3b_">
#   <caption>SWIFT_UI - impact of similarity function by hits@10</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >similarity_function</th>
#       <th class="col_heading level0 col1" >analyzer</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08c3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08c3b_row0_col0" class="data row0 col0" >bm25</td>
#       <td id="T_08c3b_row0_col1" class="data row0 col1" >stop-english_standard_analyzer</td>
#       <td id="T_08c3b_row0_col2" class="data row0 col2" >0.940217</td>
#       <td id="T_08c3b_row0_col3" class="data row0 col3" >0.864130</td>
#       <td id="T_08c3b_row0_col4" class="data row0 col4" >0.804348</td>
#       <td id="T_08c3b_row0_col5" class="data row0 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_08c3b_row1_col0" class="data row1 col0" >dfi</td>
#       <td id="T_08c3b_row1_col1" class="data row1 col1" >stop-english_standard_analyzer</td>
#       <td id="T_08c3b_row1_col2" class="data row1 col2" >0.940217</td>
#       <td id="T_08c3b_row1_col3" class="data row1 col3" >0.864130</td>
#       <td id="T_08c3b_row1_col4" class="data row1 col4" >0.798913</td>
#       <td id="T_08c3b_row1_col5" class="data row1 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_08c3b_row2_col0" class="data row2 col0" >ib</td>
#       <td id="T_08c3b_row2_col1" class="data row2 col1" >stop-english_standard_analyzer</td>
#       <td id="T_08c3b_row2_col2" class="data row2 col2" >0.940217</td>
#       <td id="T_08c3b_row2_col3" class="data row2 col3" >0.864130</td>
#       <td id="T_08c3b_row2_col4" class="data row2 col4" >0.798913</td>
#       <td id="T_08c3b_row2_col5" class="data row2 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_08c3b_row3_col0" class="data row3 col0" >lm_d</td>
#       <td id="T_08c3b_row3_col1" class="data row3 col1" >stop-english_standard_analyzer</td>
#       <td id="T_08c3b_row3_col2" class="data row3 col2" >0.940217</td>
#       <td id="T_08c3b_row3_col3" class="data row3 col3" >0.880435</td>
#       <td id="T_08c3b_row3_col4" class="data row3 col4" >0.793478</td>
#       <td id="T_08c3b_row3_col5" class="data row3 col5" >0.592391</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_08c3b_row4_col0" class="data row4 col0" >tfidf</td>
#       <td id="T_08c3b_row4_col1" class="data row4 col1" >stop-english_standard_analyzer</td>
#       <td id="T_08c3b_row4_col2" class="data row4 col2" >0.918478</td>
#       <td id="T_08c3b_row4_col3" class="data row4 col3" >0.847826</td>
#       <td id="T_08c3b_row4_col4" class="data row4 col4" >0.788043</td>
#       <td id="T_08c3b_row4_col5" class="data row4 col5" >0.570652</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_08c3b_row5_col0" class="data row5 col0" >lm_jm</td>
#       <td id="T_08c3b_row5_col1" class="data row5 col1" >stop-english_standard_analyzer</td>
#       <td id="T_08c3b_row5_col2" class="data row5 col2" >0.875000</td>
#       <td id="T_08c3b_row5_col3" class="data row5 col3" >0.782609</td>
#       <td id="T_08c3b_row5_col4" class="data row5 col4" >0.711957</td>
#       <td id="T_08c3b_row5_col5" class="data row5 col5" >0.510870</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_08c3b_row6_col0" class="data row6 col0" >dfr</td>
#       <td id="T_08c3b_row6_col1" class="data row6 col1" >stop-english_standard_analyzer</td>
#       <td id="T_08c3b_row6_col2" class="data row6 col2" >0.869565</td>
#       <td id="T_08c3b_row6_col3" class="data row6 col3" >0.815217</td>
#       <td id="T_08c3b_row6_col4" class="data row6 col4" >0.744565</td>
#       <td id="T_08c3b_row6_col5" class="data row6 col5" >0.538043</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row7" class="row_heading level0 row7" >13</th>
#       <td id="T_08c3b_row7_col0" class="data row7 col0" >tfidf</td>
#       <td id="T_08c3b_row7_col1" class="data row7 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_08c3b_row7_col2" class="data row7 col2" >0.945652</td>
#       <td id="T_08c3b_row7_col3" class="data row7 col3" >0.902174</td>
#       <td id="T_08c3b_row7_col4" class="data row7 col4" >0.798913</td>
#       <td id="T_08c3b_row7_col5" class="data row7 col5" >0.543478</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_08c3b_row8_col0" class="data row8 col0" >dfi</td>
#       <td id="T_08c3b_row8_col1" class="data row8 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_08c3b_row8_col2" class="data row8 col2" >0.940217</td>
#       <td id="T_08c3b_row8_col3" class="data row8 col3" >0.864130</td>
#       <td id="T_08c3b_row8_col4" class="data row8 col4" >0.798913</td>
#       <td id="T_08c3b_row8_col5" class="data row8 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_08c3b_row9_col0" class="data row9 col0" >ib</td>
#       <td id="T_08c3b_row9_col1" class="data row9 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_08c3b_row9_col2" class="data row9 col2" >0.940217</td>
#       <td id="T_08c3b_row9_col3" class="data row9 col3" >0.864130</td>
#       <td id="T_08c3b_row9_col4" class="data row9 col4" >0.798913</td>
#       <td id="T_08c3b_row9_col5" class="data row9 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_08c3b_row10_col0" class="data row10 col0" >lm_d</td>
#       <td id="T_08c3b_row10_col1" class="data row10 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_08c3b_row10_col2" class="data row10 col2" >0.940217</td>
#       <td id="T_08c3b_row10_col3" class="data row10 col3" >0.875000</td>
#       <td id="T_08c3b_row10_col4" class="data row10 col4" >0.809783</td>
#       <td id="T_08c3b_row10_col5" class="data row10 col5" >0.586957</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_08c3b_row11_col0" class="data row11 col0" >bm25</td>
#       <td id="T_08c3b_row11_col1" class="data row11 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_08c3b_row11_col2" class="data row11 col2" >0.934783</td>
#       <td id="T_08c3b_row11_col3" class="data row11 col3" >0.864130</td>
#       <td id="T_08c3b_row11_col4" class="data row11 col4" >0.793478</td>
#       <td id="T_08c3b_row11_col5" class="data row11 col5" >0.581522</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row12" class="row_heading level0 row12" >11</th>
#       <td id="T_08c3b_row12_col0" class="data row12 col0" >lm_jm</td>
#       <td id="T_08c3b_row12_col1" class="data row12 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_08c3b_row12_col2" class="data row12 col2" >0.896739</td>
#       <td id="T_08c3b_row12_col3" class="data row12 col3" >0.826087</td>
#       <td id="T_08c3b_row12_col4" class="data row12 col4" >0.739130</td>
#       <td id="T_08c3b_row12_col5" class="data row12 col5" >0.521739</td>
#     </tr>
#     <tr>
#       <th id="T_08c3b_level0_row13" class="row_heading level0 row13" >3</th>
#       <td id="T_08c3b_row13_col0" class="data row13 col0" >dfr</td>
#       <td id="T_08c3b_row13_col1" class="data row13 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_08c3b_row13_col2" class="data row13 col2" >0.891304</td>
#       <td id="T_08c3b_row13_col3" class="data row13

# %%
similarity_swift_df_5 = similarity_swift_df.sort_values(['analyzer','hits@5'], ascending=False)
similarity_swift_df_5 = similarity_swift_df_5.style.set_caption("SWIFT_UI - impact of similarity function by hits@5")
similarity_swift_df_5
# Out:
# <style type="text/css">
# </style>
# <table id="T_f1971_">
#   <caption>SWIFT_UI - impact of similarity function by hits@5</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >similarity_function</th>
#       <th class="col_heading level0 col1" >analyzer</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1971_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_f1971_row0_col0" class="data row0 col0" >lm_d</td>
#       <td id="T_f1971_row0_col1" class="data row0 col1" >stop-english_standard_analyzer</td>
#       <td id="T_f1971_row0_col2" class="data row0 col2" >0.940217</td>
#       <td id="T_f1971_row0_col3" class="data row0 col3" >0.880435</td>
#       <td id="T_f1971_row0_col4" class="data row0 col4" >0.793478</td>
#       <td id="T_f1971_row0_col5" class="data row0 col5" >0.592391</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_f1971_row1_col0" class="data row1 col0" >bm25</td>
#       <td id="T_f1971_row1_col1" class="data row1 col1" >stop-english_standard_analyzer</td>
#       <td id="T_f1971_row1_col2" class="data row1 col2" >0.940217</td>
#       <td id="T_f1971_row1_col3" class="data row1 col3" >0.864130</td>
#       <td id="T_f1971_row1_col4" class="data row1 col4" >0.804348</td>
#       <td id="T_f1971_row1_col5" class="data row1 col5" >0.603261</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_f1971_row2_col0" class="data row2 col0" >dfi</td>
#       <td id="T_f1971_row2_col1" class="data row2 col1" >stop-english_standard_analyzer</td>
#       <td id="T_f1971_row2_col2" class="data row2 col2" >0.940217</td>
#       <td id="T_f1971_row2_col3" class="data row2 col3" >0.864130</td>
#       <td id="T_f1971_row2_col4" class="data row2 col4" >0.798913</td>
#       <td id="T_f1971_row2_col5" class="data row2 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_f1971_row3_col0" class="data row3 col0" >ib</td>
#       <td id="T_f1971_row3_col1" class="data row3 col1" >stop-english_standard_analyzer</td>
#       <td id="T_f1971_row3_col2" class="data row3 col2" >0.940217</td>
#       <td id="T_f1971_row3_col3" class="data row3 col3" >0.864130</td>
#       <td id="T_f1971_row3_col4" class="data row3 col4" >0.798913</td>
#       <td id="T_f1971_row3_col5" class="data row3 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_f1971_row4_col0" class="data row4 col0" >tfidf</td>
#       <td id="T_f1971_row4_col1" class="data row4 col1" >stop-english_standard_analyzer</td>
#       <td id="T_f1971_row4_col2" class="data row4 col2" >0.918478</td>
#       <td id="T_f1971_row4_col3" class="data row4 col3" >0.847826</td>
#       <td id="T_f1971_row4_col4" class="data row4 col4" >0.788043</td>
#       <td id="T_f1971_row4_col5" class="data row4 col5" >0.570652</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_f1971_row5_col0" class="data row5 col0" >dfr</td>
#       <td id="T_f1971_row5_col1" class="data row5 col1" >stop-english_standard_analyzer</td>
#       <td id="T_f1971_row5_col2" class="data row5 col2" >0.869565</td>
#       <td id="T_f1971_row5_col3" class="data row5 col3" >0.815217</td>
#       <td id="T_f1971_row5_col4" class="data row5 col4" >0.744565</td>
#       <td id="T_f1971_row5_col5" class="data row5 col5" >0.538043</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_f1971_row6_col0" class="data row6 col0" >lm_jm</td>
#       <td id="T_f1971_row6_col1" class="data row6 col1" >stop-english_standard_analyzer</td>
#       <td id="T_f1971_row6_col2" class="data row6 col2" >0.875000</td>
#       <td id="T_f1971_row6_col3" class="data row6 col3" >0.782609</td>
#       <td id="T_f1971_row6_col4" class="data row6 col4" >0.711957</td>
#       <td id="T_f1971_row6_col5" class="data row6 col5" >0.510870</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row7" class="row_heading level0 row7" >13</th>
#       <td id="T_f1971_row7_col0" class="data row7 col0" >tfidf</td>
#       <td id="T_f1971_row7_col1" class="data row7 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_f1971_row7_col2" class="data row7 col2" >0.945652</td>
#       <td id="T_f1971_row7_col3" class="data row7 col3" >0.902174</td>
#       <td id="T_f1971_row7_col4" class="data row7 col4" >0.798913</td>
#       <td id="T_f1971_row7_col5" class="data row7 col5" >0.543478</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_f1971_row8_col0" class="data row8 col0" >lm_d</td>
#       <td id="T_f1971_row8_col1" class="data row8 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_f1971_row8_col2" class="data row8 col2" >0.940217</td>
#       <td id="T_f1971_row8_col3" class="data row8 col3" >0.875000</td>
#       <td id="T_f1971_row8_col4" class="data row8 col4" >0.809783</td>
#       <td id="T_f1971_row8_col5" class="data row8 col5" >0.586957</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_f1971_row9_col0" class="data row9 col0" >bm25</td>
#       <td id="T_f1971_row9_col1" class="data row9 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_f1971_row9_col2" class="data row9 col2" >0.934783</td>
#       <td id="T_f1971_row9_col3" class="data row9 col3" >0.864130</td>
#       <td id="T_f1971_row9_col4" class="data row9 col4" >0.793478</td>
#       <td id="T_f1971_row9_col5" class="data row9 col5" >0.581522</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_f1971_row10_col0" class="data row10 col0" >dfi</td>
#       <td id="T_f1971_row10_col1" class="data row10 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_f1971_row10_col2" class="data row10 col2" >0.940217</td>
#       <td id="T_f1971_row10_col3" class="data row10 col3" >0.864130</td>
#       <td id="T_f1971_row10_col4" class="data row10 col4" >0.798913</td>
#       <td id="T_f1971_row10_col5" class="data row10 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row11" class="row_heading level0 row11" >7</th>
#       <td id="T_f1971_row11_col0" class="data row11 col0" >ib</td>
#       <td id="T_f1971_row11_col1" class="data row11 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_f1971_row11_col2" class="data row11 col2" >0.940217</td>
#       <td id="T_f1971_row11_col3" class="data row11 col3" >0.864130</td>
#       <td id="T_f1971_row11_col4" class="data row11 col4" >0.798913</td>
#       <td id="T_f1971_row11_col5" class="data row11 col5" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row12" class="row_heading level0 row12" >3</th>
#       <td id="T_f1971_row12_col0" class="data row12 col0" >dfr</td>
#       <td id="T_f1971_row12_col1" class="data row12 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_f1971_row12_col2" class="data row12 col2" >0.891304</td>
#       <td id="T_f1971_row12_col3" class="data row12 col3" >0.836957</td>
#       <td id="T_f1971_row12_col4" class="data row12 col4" >0.744565</td>
#       <td id="T_f1971_row12_col5" class="data row12 col5" >0.516304</td>
#     </tr>
#     <tr>
#       <th id="T_f1971_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_f1971_row13_col0" class="data row13 col0" >lm_jm</td>
#       <td id="T_f1971_row13_col1" class="data row13 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_f1971_row13_col2" class="data row13 col2" >0.896739</td>
#       <td id="T_f1971_row13_col3" class="data row13 c

# %% [markdown]
# #### SQUAD_10k

# %%
similarity_squad_df_10 = similarity_squad_df.sort_values(['analyzer','hits@10'], ascending=False)
similarity_squad_df_10 = similarity_squad_df_10.style.set_caption("SQUAD_10k - impact of similarity function by hits@10")
similarity_squad_df_10
# Out:
# <style type="text/css">
# </style>
# <table id="T_98c11_">
#   <caption>SQUAD_10k - impact of similarity function by hits@10</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >similarity_function</th>
#       <th class="col_heading level0 col1" >analyzer</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98c11_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_98c11_row0_col0" class="data row0 col0" >dfi</td>
#       <td id="T_98c11_row0_col1" class="data row0 col1" >stop-english_standard_analyzer</td>
#       <td id="T_98c11_row0_col2" class="data row0 col2" >0.905000</td>
#       <td id="T_98c11_row0_col3" class="data row0 col3" >0.871000</td>
#       <td id="T_98c11_row0_col4" class="data row0 col4" >0.830000</td>
#       <td id="T_98c11_row0_col5" class="data row0 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_98c11_row1_col0" class="data row1 col0" >bm25</td>
#       <td id="T_98c11_row1_col1" class="data row1 col1" >stop-english_standard_analyzer</td>
#       <td id="T_98c11_row1_col2" class="data row1 col2" >0.904000</td>
#       <td id="T_98c11_row1_col3" class="data row1 col3" >0.868000</td>
#       <td id="T_98c11_row1_col4" class="data row1 col4" >0.835000</td>
#       <td id="T_98c11_row1_col5" class="data row1 col5" >0.716000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_98c11_row2_col0" class="data row2 col0" >ib</td>
#       <td id="T_98c11_row2_col1" class="data row2 col1" >stop-english_standard_analyzer</td>
#       <td id="T_98c11_row2_col2" class="data row2 col2" >0.904000</td>
#       <td id="T_98c11_row2_col3" class="data row2 col3" >0.871000</td>
#       <td id="T_98c11_row2_col4" class="data row2 col4" >0.830000</td>
#       <td id="T_98c11_row2_col5" class="data row2 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_98c11_row3_col0" class="data row3 col0" >dfr</td>
#       <td id="T_98c11_row3_col1" class="data row3 col1" >stop-english_standard_analyzer</td>
#       <td id="T_98c11_row3_col2" class="data row3 col2" >0.896000</td>
#       <td id="T_98c11_row3_col3" class="data row3 col3" >0.848000</td>
#       <td id="T_98c11_row3_col4" class="data row3 col4" >0.818000</td>
#       <td id="T_98c11_row3_col5" class="data row3 col5" >0.698000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_98c11_row4_col0" class="data row4 col0" >lm_d</td>
#       <td id="T_98c11_row4_col1" class="data row4 col1" >stop-english_standard_analyzer</td>
#       <td id="T_98c11_row4_col2" class="data row4 col2" >0.887000</td>
#       <td id="T_98c11_row4_col3" class="data row4 col3" >0.839000</td>
#       <td id="T_98c11_row4_col4" class="data row4 col4" >0.793000</td>
#       <td id="T_98c11_row4_col5" class="data row4 col5" >0.656000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_98c11_row5_col0" class="data row5 col0" >tfidf</td>
#       <td id="T_98c11_row5_col1" class="data row5 col1" >stop-english_standard_analyzer</td>
#       <td id="T_98c11_row5_col2" class="data row5 col2" >0.882000</td>
#       <td id="T_98c11_row5_col3" class="data row5 col3" >0.839000</td>
#       <td id="T_98c11_row5_col4" class="data row5 col4" >0.800000</td>
#       <td id="T_98c11_row5_col5" class="data row5 col5" >0.650000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_98c11_row6_col0" class="data row6 col0" >lm_jm</td>
#       <td id="T_98c11_row6_col1" class="data row6 col1" >stop-english_standard_analyzer</td>
#       <td id="T_98c11_row6_col2" class="data row6 col2" >0.877000</td>
#       <td id="T_98c11_row6_col3" class="data row6 col3" >0.833000</td>
#       <td id="T_98c11_row6_col4" class="data row6 col4" >0.787000</td>
#       <td id="T_98c11_row6_col5" class="data row6 col5" >0.666000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_98c11_row7_col0" class="data row7 col0" >bm25</td>
#       <td id="T_98c11_row7_col1" class="data row7 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_98c11_row7_col2" class="data row7 col2" >0.924000</td>
#       <td id="T_98c11_row7_col3" class="data row7 col3" >0.902000</td>
#       <td id="T_98c11_row7_col4" class="data row7 col4" >0.867000</td>
#       <td id="T_98c11_row7_col5" class="data row7 col5" >0.764000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_98c11_row8_col0" class="data row8 col0" >tfidf</td>
#       <td id="T_98c11_row8_col1" class="data row8 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_98c11_row8_col2" class="data row8 col2" >0.909000</td>
#       <td id="T_98c11_row8_col3" class="data row8 col3" >0.873000</td>
#       <td id="T_98c11_row8_col4" class="data row8 col4" >0.837000</td>
#       <td id="T_98c11_row8_col5" class="data row8 col5" >0.690000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_98c11_row9_col0" class="data row9 col0" >dfr</td>
#       <td id="T_98c11_row9_col1" class="data row9 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_98c11_row9_col2" class="data row9 col2" >0.906000</td>
#       <td id="T_98c11_row9_col3" class="data row9 col3" >0.881000</td>
#       <td id="T_98c11_row9_col4" class="data row9 col4" >0.853000</td>
#       <td id="T_98c11_row9_col5" class="data row9 col5" >0.735000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_98c11_row10_col0" class="data row10 col0" >lm_d</td>
#       <td id="T_98c11_row10_col1" class="data row10 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_98c11_row10_col2" class="data row10 col2" >0.906000</td>
#       <td id="T_98c11_row10_col3" class="data row10 col3" >0.870000</td>
#       <td id="T_98c11_row10_col4" class="data row10 col4" >0.834000</td>
#       <td id="T_98c11_row10_col5" class="data row10 col5" >0.698000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row11" class="row_heading level0 row11" >5</th>
#       <td id="T_98c11_row11_col0" class="data row11 col0" >dfi</td>
#       <td id="T_98c11_row11_col1" class="data row11 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_98c11_row11_col2" class="data row11 col2" >0.904000</td>
#       <td id="T_98c11_row11_col3" class="data row11 col3" >0.871000</td>
#       <td id="T_98c11_row11_col4" class="data row11 col4" >0.830000</td>
#       <td id="T_98c11_row11_col5" class="data row11 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row12" class="row_heading level0 row12" >7</th>
#       <td id="T_98c11_row12_col0" class="data row12 col0" >ib</td>
#       <td id="T_98c11_row12_col1" class="data row12 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_98c11_row12_col2" class="data row12 col2" >0.904000</td>
#       <td id="T_98c11_row12_col3" class="data row12 col3" >0.871000</td>
#       <td id="T_98c11_row12_col4" class="data row12 col4" >0.830000</td>
#       <td id="T_98c11_row12_col5" class="data row12 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_98c11_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_98c11_row13_col0" class="data row13 col0" >lm_jm</td>
#       <td id="T_98c11_row13_col1" class="data row13 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_98c11_row13_col2" class="data row13 col2" >0.895000</td>
#       <td id="T_98c11_row13_col3" class="data row13

# %%
similarity_squad_df_5 = similarity_squad_df.sort_values(['analyzer','hits@5'], ascending=False)
similarity_squad_df_5 = similarity_squad_df_5.style.set_caption("SQUAD_10k - impact of similarity function by hits@5")
similarity_squad_df_5
# Out:
# <style type="text/css">
# </style>
# <table id="T_67cd6_">
#   <caption>SQUAD_10k - impact of similarity function by hits@5</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >similarity_function</th>
#       <th class="col_heading level0 col1" >analyzer</th>
#       <th class="col_heading level0 col2" >hits@10</th>
#       <th class="col_heading level0 col3" >hits@5</th>
#       <th class="col_heading level0 col4" >hits@3</th>
#       <th class="col_heading level0 col5" >hits@1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67cd6_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_67cd6_row0_col0" class="data row0 col0" >dfi</td>
#       <td id="T_67cd6_row0_col1" class="data row0 col1" >stop-english_standard_analyzer</td>
#       <td id="T_67cd6_row0_col2" class="data row0 col2" >0.905000</td>
#       <td id="T_67cd6_row0_col3" class="data row0 col3" >0.871000</td>
#       <td id="T_67cd6_row0_col4" class="data row0 col4" >0.830000</td>
#       <td id="T_67cd6_row0_col5" class="data row0 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_67cd6_row1_col0" class="data row1 col0" >ib</td>
#       <td id="T_67cd6_row1_col1" class="data row1 col1" >stop-english_standard_analyzer</td>
#       <td id="T_67cd6_row1_col2" class="data row1 col2" >0.904000</td>
#       <td id="T_67cd6_row1_col3" class="data row1 col3" >0.871000</td>
#       <td id="T_67cd6_row1_col4" class="data row1 col4" >0.830000</td>
#       <td id="T_67cd6_row1_col5" class="data row1 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_67cd6_row2_col0" class="data row2 col0" >bm25</td>
#       <td id="T_67cd6_row2_col1" class="data row2 col1" >stop-english_standard_analyzer</td>
#       <td id="T_67cd6_row2_col2" class="data row2 col2" >0.904000</td>
#       <td id="T_67cd6_row2_col3" class="data row2 col3" >0.868000</td>
#       <td id="T_67cd6_row2_col4" class="data row2 col4" >0.835000</td>
#       <td id="T_67cd6_row2_col5" class="data row2 col5" >0.716000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_67cd6_row3_col0" class="data row3 col0" >dfr</td>
#       <td id="T_67cd6_row3_col1" class="data row3 col1" >stop-english_standard_analyzer</td>
#       <td id="T_67cd6_row3_col2" class="data row3 col2" >0.896000</td>
#       <td id="T_67cd6_row3_col3" class="data row3 col3" >0.848000</td>
#       <td id="T_67cd6_row3_col4" class="data row3 col4" >0.818000</td>
#       <td id="T_67cd6_row3_col5" class="data row3 col5" >0.698000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_67cd6_row4_col0" class="data row4 col0" >lm_d</td>
#       <td id="T_67cd6_row4_col1" class="data row4 col1" >stop-english_standard_analyzer</td>
#       <td id="T_67cd6_row4_col2" class="data row4 col2" >0.887000</td>
#       <td id="T_67cd6_row4_col3" class="data row4 col3" >0.839000</td>
#       <td id="T_67cd6_row4_col4" class="data row4 col4" >0.793000</td>
#       <td id="T_67cd6_row4_col5" class="data row4 col5" >0.656000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_67cd6_row5_col0" class="data row5 col0" >tfidf</td>
#       <td id="T_67cd6_row5_col1" class="data row5 col1" >stop-english_standard_analyzer</td>
#       <td id="T_67cd6_row5_col2" class="data row5 col2" >0.882000</td>
#       <td id="T_67cd6_row5_col3" class="data row5 col3" >0.839000</td>
#       <td id="T_67cd6_row5_col4" class="data row5 col4" >0.800000</td>
#       <td id="T_67cd6_row5_col5" class="data row5 col5" >0.650000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_67cd6_row6_col0" class="data row6 col0" >lm_jm</td>
#       <td id="T_67cd6_row6_col1" class="data row6 col1" >stop-english_standard_analyzer</td>
#       <td id="T_67cd6_row6_col2" class="data row6 col2" >0.877000</td>
#       <td id="T_67cd6_row6_col3" class="data row6 col3" >0.833000</td>
#       <td id="T_67cd6_row6_col4" class="data row6 col4" >0.787000</td>
#       <td id="T_67cd6_row6_col5" class="data row6 col5" >0.666000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_67cd6_row7_col0" class="data row7 col0" >bm25</td>
#       <td id="T_67cd6_row7_col1" class="data row7 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_67cd6_row7_col2" class="data row7 col2" >0.924000</td>
#       <td id="T_67cd6_row7_col3" class="data row7 col3" >0.902000</td>
#       <td id="T_67cd6_row7_col4" class="data row7 col4" >0.867000</td>
#       <td id="T_67cd6_row7_col5" class="data row7 col5" >0.764000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_67cd6_row8_col0" class="data row8 col0" >dfr</td>
#       <td id="T_67cd6_row8_col1" class="data row8 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_67cd6_row8_col2" class="data row8 col2" >0.906000</td>
#       <td id="T_67cd6_row8_col3" class="data row8 col3" >0.881000</td>
#       <td id="T_67cd6_row8_col4" class="data row8 col4" >0.853000</td>
#       <td id="T_67cd6_row8_col5" class="data row8 col5" >0.735000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row9" class="row_heading level0 row9" >13</th>
#       <td id="T_67cd6_row9_col0" class="data row9 col0" >tfidf</td>
#       <td id="T_67cd6_row9_col1" class="data row9 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_67cd6_row9_col2" class="data row9 col2" >0.909000</td>
#       <td id="T_67cd6_row9_col3" class="data row9 col3" >0.873000</td>
#       <td id="T_67cd6_row9_col4" class="data row9 col4" >0.837000</td>
#       <td id="T_67cd6_row9_col5" class="data row9 col5" >0.690000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_67cd6_row10_col0" class="data row10 col0" >dfi</td>
#       <td id="T_67cd6_row10_col1" class="data row10 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_67cd6_row10_col2" class="data row10 col2" >0.904000</td>
#       <td id="T_67cd6_row10_col3" class="data row10 col3" >0.871000</td>
#       <td id="T_67cd6_row10_col4" class="data row10 col4" >0.830000</td>
#       <td id="T_67cd6_row10_col5" class="data row10 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row11" class="row_heading level0 row11" >7</th>
#       <td id="T_67cd6_row11_col0" class="data row11 col0" >ib</td>
#       <td id="T_67cd6_row11_col1" class="data row11 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_67cd6_row11_col2" class="data row11 col2" >0.904000</td>
#       <td id="T_67cd6_row11_col3" class="data row11 col3" >0.871000</td>
#       <td id="T_67cd6_row11_col4" class="data row11 col4" >0.830000</td>
#       <td id="T_67cd6_row11_col5" class="data row11 col5" >0.717000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row12" class="row_heading level0 row12" >9</th>
#       <td id="T_67cd6_row12_col0" class="data row12 col0" >lm_d</td>
#       <td id="T_67cd6_row12_col1" class="data row12 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_67cd6_row12_col2" class="data row12 col2" >0.906000</td>
#       <td id="T_67cd6_row12_col3" class="data row12 col3" >0.870000</td>
#       <td id="T_67cd6_row12_col4" class="data row12 col4" >0.834000</td>
#       <td id="T_67cd6_row12_col5" class="data row12 col5" >0.698000</td>
#     </tr>
#     <tr>
#       <th id="T_67cd6_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_67cd6_row13_col0" class="data row13 col0" >lm_jm</td>
#       <td id="T_67cd6_row13_col1" class="data row13 col1" >stemmer-porter2_standard_analyzer</td>
#       <td id="T_67cd6_row13_col2" class="data row13 col2" >0.895000</td>
#       <td id="T_67cd6_row13_col3" class="data row13
